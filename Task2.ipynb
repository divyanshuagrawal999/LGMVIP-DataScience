# %% [markdown]
# Data Science Intern - LetsGrowMore
#
# Author: Divyasnhu Agrawal
#
# Task2: Image to pencil sketch with python

# %%
import cv2

# %%
from google.colab.patches import cv2_imshow
# Out:
# ---------------------------------------------------------------------------
# ModuleNotFoundError                       Traceback (most recent call last)
# Input In [2], in <module>
# ----> 1 from google.colab.patches import cv2_imshow
#
# ModuleNotFoundError: No module named 'google.colab'

# %%
image = cv2.imread('download.jpeg')
cv2_imshow(image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=RGB size=299x168 at 0x7FD5FDFE98D0>

# %%
gray_image = cv2.cvtColor(image, cv2.COLOR_BGR2GRAY) #converting into grayscale step
cv2_imshow(gray_image)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=299x168 at 0x7FD5FDF79D10>

# %%
inverted_image = 255 - gray_image #inverting step
cv2_imshow(inverted_image) #basically creating a negative image of the converted grayscale image
cv2.waitKey()
# Out:
# <PIL.Image.Image image mode=L size=299x168 at 0x7FD5FDF7D950>

# %%
blurred_image = cv2.GaussianBlur(inverted_image, (21,21),0) #GaussianFunction

# %%
#final step
inverted_blurred = 255 - blurred_image
pencil_sketch = cv2.divide(gray_image, inverted_blurred, scale = 256.0)
cv2_imshow(pencil_sketch)
cv2.waitKey(0)
# Out:
# <PIL.Image.Image image mode=L size=299x168 at 0x7FD5FDF707D0>
